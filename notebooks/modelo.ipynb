# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
caminho = "../dados/CO2_Emissions_Canada.csv"
df_raw = pd.read_csv(caminho)
df_raw.shape
# Out:
# (7385, 12)

# %%
# Remover duplicados
df_trat = df_raw.drop_duplicates()
print(f"Dataset após remover duplicatas: {df_trat.shape}")

# Remover coluna redundante
base = df_trat.drop(columns=['Fuel Consumption Comb (mpg)'])
# Out:
# Dataset após remover duplicatas: (6282, 12)

# %%
# Separar target e features
target = 'CO2 Emissions(g/km)'

# %%
# Features numéricas
num_features = [
    'Engine Size(L)',
    'Cylinders',
    'Fuel Consumption City (L/100 km)',
    'Fuel Consumption Hwy (L/100 km)',
    'Fuel Consumption Comb (L/100 km)'
]

# Features categóricas
cat_features = [
    'Make',
    'Model',
    'Vehicle Class',
    'Transmission',
    'Fuel Type'
]

features = num_features + cat_features

# %%
X = base[features]
y = base[target]

# %%
print("Features (X):")
print(X.head())
# Out:
# Features (X):
#    Engine Size(L)  Cylinders  Fuel Consumption City (L/100 km)  \
# 0             2.0          4                               9.9
# 1             2.4          4                              11.2
# 2             1.5          4                               6.0
# 3             3.5          6                              12.7
# 4             3.5          6                              12.1
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)   Make  \
# 0                              6.7                               8.5  ACURA
# 1                              7.7                               9.6  ACURA
# 2                              5.8                               5.9  ACURA
# 3                              9.1                              11.1  ACURA
# 4                              8.7                              10.6  ACURA
#
#         Model Vehicle Class Transmission Fuel Type
# 0         ILX       COMPACT          AS5         Z
# 1         ILX       COMPACT           M6         Z
# 2  ILX HYBRID       COMPACT          AV7         Z
# 3     MDX 4WD   SUV - SMALL          AS6         Z
# 4     RDX AWD   SUV - SMALL          AS6         Z

# %%
print("\nTarget (y):")
print(y.head())
# Out:
# Target (y):
# 0    196
# 1    221
# 2    136
# 3    255
# 4    244
# Name: CO2 Emissions(g/km), dtype: int64

# %% [markdown]
# ### Transformar categóricas em numéricas (One-Hot Encoding ou Label Encoding)
#     Usamos o one hot encoder pois não há uma sequência lógica nos dados categóricos.

# %%
X = pd.get_dummies(X, columns=cat_features)

# %%
X
# Out:
#       Engine Size(L)  Cylinders  Fuel Consumption City (L/100 km)  \
# 0                2.0          4                               9.9
# 1                2.4          4                              11.2
# 2                1.5          4                               6.0
# 3                3.5          6                              12.7
# 4                3.5          6                              12.1
# ...              ...        ...                               ...
# 7380             2.0          4                              10.7
# 7381             2.0          4                              11.2
# 7382             2.0          4                              11.7
# 7383             2.0          4                              11.2
# 7384             2.0          4                              12.2
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                                 6.7                               8.5
# 1                                 7.7                               9.6
# 2                                 5.8                               5.9
# 3                                 9.1                              11.1
# 4                                 8.7                              10.6
# ...                               ...                               ...
# 7380                              7.7                               9.4
# 7381                              8.3                               9.9
# 7382                              8.6                              10.3
# 7383                              8.3                               9.9
# 7384                              8.7                              10.7
#
#       Make_ACURA  Make_ALFA ROMEO  Make_ASTON MARTIN  Make_AUDI  Make_BENTLEY  \
# 0           True            False              False      False         False
# 1           True            False              False      False         False
# 2           True            False              False      False         False
# 3           True            False              False      False         False
# 4           True            False              False      False         False
# ...          ...              ...                ...        ...           ...
# 7380       False            False              False      False         False
# 7381       False            False              False      False         False
# 7382       False            False              False      False         False
# 7383       False            False              False      False         False
# 7384       False            False              False      False         False
#
#       ...  Transmission_AV7  Transmission_AV8  Transmission_M5  \
# 0     ...             False             False            False
# 1     ...             False             False            False
# 2     ...              True             False            False
# 3     ...             False             False            False
# 4     ...             False             False            False
# ...   ...               ...               ...              ...
# 7380  ...             False             False            False
# 7381  ...             False             False            False
# 7382  ...             False             False            False
# 7383  ...             False             False            False
# 7384  ...             False             False            False
#
#       Transmission_M6  Transmission_M7  Fuel Type_D  Fuel Type_E  Fuel Type_N  \
# 0               False            False        False        False        False
# 1                True            False        False        False        False
# 2               False            False        False        False        False
# 3               False            False        False        False        False
# 4               False            False        False        False        False
# ...               ...              ...          ...          ...          ...
# 7380            False            False        False        False        False
# 7381            False            False        False        False        False
# 7382            False            False        False        False        False
# 7383            False            False        False        False        False
# 7384            False            False        False        False        False
#
#       Fuel Type_X  Fuel Type_Z
# 0           False         True
# 1           False         True
# 2           False         True
# 3           False         True
# 4           False         True
# ...           ...          ...
# 7380        False         True
# 7381        False         True
# 7382        False         True
# 7383        False         True
# 7384        False         True
#
# [6282 rows x 2148 columns]

# %% [markdown]
# ### Padronizar ou normalizar features numéricas
#     A normalização neste caso não é bem vista, visto que é sensível a outliers então um carro com um consumo muito alto de combustivel estaria em uma mesma escala de carros com combustiveis normais, já a Padronização é ótimo para esses tipos de caso.

# %%
scaler = StandardScaler()

# %%
X[num_features] = scaler.fit_transform(X[num_features])

# %%
X
# Out:
#       Engine Size(L)  Cylinders  Fuel Consumption City (L/100 km)  \
# 0          -0.851086  -0.876934                         -0.762844
# 1          -0.558066  -0.876934                         -0.396934
# 2          -1.217362  -0.876934                         -1.860575
# 3           0.247740   0.206429                          0.025270
# 4           0.247740   0.206429                         -0.143611
# ...              ...        ...                               ...
# 7380       -0.851086  -0.876934                         -0.537668
# 7381       -0.851086  -0.876934                         -0.396934
# 7382       -0.851086  -0.876934                         -0.256199
# 7383       -0.851086  -0.876934                         -0.396934
# 7384       -0.851086  -0.876934                         -0.115464
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                           -1.040321                         -0.854490
# 1                           -0.601475                         -0.481184
# 2                           -1.435283                         -1.736851
# 3                            0.012910                          0.027870
# 4                           -0.162629                         -0.141815
# ...                               ...                               ...
# 7380                        -0.601475                         -0.549058
# 7381                        -0.338167                         -0.379373
# 7382                        -0.206513                         -0.243625
# 7383                        -0.338167                         -0.379373
# 7384                        -0.162629                         -0.107878
#
#       Make_ACURA  Make_ALFA ROMEO  Make_ASTON MARTIN  Make_AUDI  Make_BENTLEY  \
# 0           True            False              False      False         False
# 1           True            False              False      False         False
# 2           True            False              False      False         False
# 3           True            False              False      False         False
# 4           True            False              False      False         False
# ...          ...              ...                ...        ...           ...
# 7380       False            False              False      False         False
# 7381       False            False              False      False         False
# 7382       False            False              False      False         False
# 7383       False            False              False      False         False
# 7384       False            False              False      False         False
#
#       ...  Transmission_AV7  Transmission_AV8  Transmission_M5  \
# 0     ...             False             False            False
# 1     ...             False             False            False
# 2     ...              True             False            False
# 3     ...             False             False            False
# 4     ...             False             False            False
# ...   ...               ...               ...              ...
# 7380  ...             False             False            False
# 7381  ...             False             False            False
# 7382  ...             False             False            False
# 7383  ...             False             False            False
# 7384  ...             False             False            False
#
#       Transmission_M6  Transmission_M7  Fuel Type_D  Fuel Type_E  Fuel Type_N  \
# 0               False            False        False        False        False
# 1                True            False        False        False        False
# 2               False            False        False        False        False
# 3               False            False        False        False        False
# 4               False            False        False        False        False
# ...               ...              ...          ...          ...          ...
# 7380            False            False        False        False        False
# 7381            False            False        False        False        False
# 7382            False            False        False        False        False
# 7383            False            False        False        False        False
# 7384            False            False        False        False        False
#
#       Fuel Type_X  Fuel Type_Z
# 0           False         True
# 1           False         True
# 2           False         True
# 3           False         True
# 4           False         True
# ...           ...          ...
# 7380        False         True
# 7381        False         True
# 7382        False         True
# 7383        False         True
# 7384        False         True
#
# [6282 rows x 2148 columns]

# %% [markdown]
# ### Dividir dataset em treino/teste
# ### Treinar o modelo de regressão
